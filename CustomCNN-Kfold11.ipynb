# %%
# IMPORT LIBRARIES & PERSIAPAN DATASET UTUH (TANPA PREPROCESS.IPYNB)

import os
import pathlib
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import AdamW, SGD, RMSprop, Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.utils import class_weight
from tensorflow.keras.losses import CategoricalFocalCrossentropy
from keras.src.backend.common.keras_tensor import KerasTensor


print("\n[INFO] Libraries berhasil dimuat!")
# Out:
# [INFO] Libraries berhasil dimuat!

# %%
# --- KONFIGURASI GLOBAL ---
DATASET_DIR = pathlib.Path("data_cropped") # Pastikan foldernya benar
IMG_SIZE = 224 # Menggantikan img_height
BATCH_SIZE = 16 # Menggantikan batch_size
LEARNING_RATE = 0.0005
EPOCHS = 75
K_FOLDS = 5
DROPOUT_RATE = 0.3
OPTIMIZER_NAME = 'rmsprop'

# --- LOAD PATH DATASET ---
all_image_paths = list(DATASET_DIR.glob('*/*.png'))
all_image_paths = [str(path) for path in all_image_paths]

class_names_list = sorted([item.name for item in DATASET_DIR.glob('*') if item.is_dir()])
label_to_index = dict((name, index) for index, name in enumerate(class_names_list))
all_image_labels = [label_to_index[pathlib.Path(path).parent.name] for path in all_image_paths]

X = np.array(all_image_paths)
y = np.array(all_image_labels)

print(f"[INFO] Total dataset siap K-Fold: {len(X)} gambar")

# --- FUNGSI PIPELINE DATA (MASKING & AUGMENTASI) ---
def process_path(file_path, label):
    img = tf.io.read_file(file_path)
    img = tf.io.decode_image(img, channels=4, expand_animations=False)
    img = tf.cast(img, tf.float32)
    # Masking
    rgb = img[..., :3]
    alpha = img[..., 3:4] / 255.0
    img_fixed = rgb * alpha
    # Resize & Normalisasi
    img_resized = tf.image.resize(img_fixed, [IMG_SIZE, IMG_SIZE])
    img_final = img_resized / 255.0
    img_final.set_shape([IMG_SIZE, IMG_SIZE, 3])
    
    label_one_hot = tf.one_hot(label, depth=len(class_names_list))
    return img_final, label_one_hot

data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomTranslation(height_factor=0.1, width_factor=0.1)
])

def augment(image, label):
    return data_augmentation(image, training=True), label
# Out:
# [INFO] Total dataset siap K-Fold: 908 gambar

# %%
# MEMBANGUN ARSITEKTUR CUSTOM CNN 

def build_aflatoxin_uv_cnn():
    inputs = tf.keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3), name="Input_Layer")
    
    x = layers.Conv2D(16, (3, 3), activation='relu', padding='same', name="Conv1")(inputs)
    x = layers.BatchNormalization(name="BatchNorm1")(x) # <- Tambahan agar model cepat fokus
    x = layers.MaxPooling2D((2, 2), name="Pool1")(x)
    
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same', name="Conv2")(x)
    x = layers.BatchNormalization(name="BatchNorm2")(x) # <- memastikan sinyal fitur pendaran UV tidak meredup atau meledak (vanishing/exploding gradients) saat masuk ke lapisan yang lebih dalam
    x = layers.MaxPooling2D((2, 2), name="Pool2")(x)
    
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same', name="Conv3")(x)
    x = layers.BatchNormalization(name="BatchNorm3")(x)
    x = layers.MaxPooling2D((2, 2), name="Pool3")(x)
    
    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same', name="Conv4")(x)
    x = layers.BatchNormalization(name="BatchNorm4")(x)
    x = layers.MaxPooling2D((2, 2), name="Pool4")(x)
    
    # --- DUAL POOLING (Mendeteksi Kecerahan Tertinggi & Luas Area) ---
    max_pool = layers.GlobalMaxPooling2D(name="Peak_Brightness_Detector")(x) # <- Bertugas mencari titik pendaran paling terang (Intensitas puncak racun).
    avg_pool = layers.GlobalAveragePooling2D(name="Spatial_Extent_Detector")(x) # <- Bertugas menghitung luas sebaran pendaran secara keseluruhan di permukaan jagung.
    merged = layers.Concatenate(name="Feature_Fusion")([max_pool, avg_pool]) # <- memberikan gambaran yang lebih lengkap tentang pola pendaran UV pada jagung: seberapa terang racunnya, dan seberapa luas serangannya.
    
    # --- KEPALA KLASIFIKASI DENGAN OTAK DIPERBESAR ---
    # 2. Naikkan neuron dari 128 ke 256 agar bisa menyimpan pola rumit
    x = layers.Dense(256, activation='relu', name="Dense_Hidden_1")(merged)
    x = layers.Dropout(DROPOUT_RATE)(x)
    # 2. Hakim Penengah / Sistem Corong (Merangkum 256 laporan menjadi 128 intisari)
    x = layers.Dense(128, activation='relu', name="Dense_Hidden_2")(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(4, activation='softmax', name="Output_Classification")(x)
    
    model = models.Model(inputs=inputs, outputs=outputs, name="Custom_CNN_Dual_Pooling")
    return model

# Print summary sekali saja di awal
dummy_model = build_aflatoxin_uv_cnn()
print("="*60)
print("ARSITEKTUR MODEL BERHASIL DIBANGUN")
print("="*60)
dummy_model.summary()
# Out:
# ============================================================
# ARSITEKTUR MODEL BERHASIL DIBANGUN
# ============================================================
# Model: "Custom_CNN_Dual_Pooling"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ Input_Layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv1 (Conv2D)      │ (None, 224, 224,  │        448 │ Input_Layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ BatchNorm1          │ (None, 224, 224,  │         64 │ Conv1[0][0]       │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Pool1               │ (None, 112, 112,  │          0 │ BatchNorm1[0][0]  │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv2 (Conv2D)      │ (None, 112, 112,  │      4,640 │ Pool1[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ BatchNorm2          │ (None, 112, 112,  │        128 │ Conv2[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Pool2               │ (None, 56, 56,    │          0 │ BatchNorm2[0][0]  │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv3 (Conv2D)      │ (None, 56, 56,    │     18,496 │ Pool2[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ BatchNorm3          │ (None, 56, 56,    │        256 │ Conv3[0][0]       │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Pool3               │ (None, 28, 28,    │          0 │ BatchNorm3[0][0]  │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Conv4 (Conv2D)      │ (None, 28, 28,    │     73,856 │ Pool3[0][0]       │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ BatchNorm4          │ (None, 28, 28,    │        512 │ Conv4[0][0]       │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Pool4               │ (None, 14, 14,    │          0 │ BatchNorm4[0][0]  │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Peak_Brightness_De… │ (None, 128)       │          0 │ Pool4[0][0]       │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Spatial_Extent_Det… │ (None, 128)       │          0 │ Pool4[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Feature_Fusion      │ (None, 256)       │          0 │ Peak_Brightness_… │
# │ (Concatenate)       │                   │            │ Spatial_Extent_D… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Dense_Hidden_1      │ (None, 256)       │     65,792 │ Feature_Fusion[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 256)       │          0 │ Dense_Hidden_1[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Dense_Hidden_2      │ (None, 128)       │     32,896 │ dropout_2[0][0]   │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 128)       │          0 │ Dense_Hidden_2[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Output_Classificat… │ (None, 4)         │        516 │ dropout_3[0][0]   │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 197,604 (771.89 KB)
#  Trainable params: 197,124 (770.02 KB)
#  Non-trainable params: 480 (1.88 KB)

# %%
# MULAI PERULANGAN K-FOLD (BAGIAN 4, 5, 6, 7, 8 MASUK KE DALAM SINI)

skf = StratifiedKFold(n_splits=K_FOLDS, shuffle=True, random_state=42)
global_accuracies = []

for fold_no, (train_index, val_index) in enumerate(skf.split(X, y), 1):
    print("\n" + "★"*60)
    print(f"🚀 MEMULAI TRAINING FOLD KE-{fold_no}")
    print("★"*60)
    
    # --- A. SETUP DATA UNTUK FOLD INI ---
    X_train_paths, X_val_paths = X[train_index], X[val_index]
    y_train_labels, y_val_labels = y[train_index], y[val_index]
    
    # ==============================================================================
    # --- TAMBAHAN BARU: OVERSAMPLING ON-THE-FLY (KHUSUS DATA LATIH) ---
    # ==============================================================================
    # Asumsi: y adalah label One-Hot Encoding (misal Kelas 4 adalah indeks ke-3)
    # 1. Cari indeks array yang merupakan Kelas 4
    class_4_indices = np.where(y_train_labels == 3)[0]
    
    # 2. Ekstrak path dan label untuk Kelas 4 tersebut
    X_train_class_4 = X_train_paths[class_4_indices]
    y_train_class_4 = y_train_labels[class_4_indices]
    
    # 3. Kloning/Duplikasi dengan menggabungkan ke data asli (Menjadi tepat 2x lipat)
    X_train_paths = np.concatenate([X_train_paths, X_train_class_4])
    y_train_labels = np.concatenate([y_train_labels, y_train_class_4])
    
    # 4. Acak (Shuffle) array agar data kloningan tidak menumpuk di akhir antrean
    shuffle_idx = np.random.permutation(len(X_train_paths))
    X_train_paths = X_train_paths[shuffle_idx]
    y_train_labels = y_train_labels[shuffle_idx]
    # ==============================================================================

    # Hitung Bobot Kelas Otomatis untuk Fold ini
    # Karena y_train_labels berupa One-Hot, kita ubah ke 1D (integer) agar sklearn tidak error
    # weights = class_weight.compute_class_weight('balanced', classes=np.unique(y_train_labels), y=y_train_labels)
    # fold_class_weights = dict(enumerate(weights))
    
    # Buat Dataset
    train_ds = tf.data.Dataset.from_tensor_slices((X_train_paths, y_train_labels))
# ... (LANJUTKAN KE KODE ASLI ANDA MULAI DARI SINI: train_ds = train_ds.map(process_path, ...))
    train_ds = train_ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)
    train_ds = train_ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)
    train_ds = train_ds.shuffle(len(X_train_paths)).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    
    val_ds = tf.data.Dataset.from_tensor_slices((X_val_paths, y_val_labels))
    val_ds = val_ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)
    val_ds = val_ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    
    # Aliasing val_ds menjadi test_ds agar kode evaluasi Anda di bawah tidak error
    test_ds = val_ds 
    
    # --- B. RESET & COMPILE MODEL (Cell 4 Lama) ---
    tf.keras.backend.clear_session()
    model = build_aflatoxin_uv_cnn()
    
    # lr_schedule = CosineDecay(initial_learning_rate=0.0005, #lr paling stabil
    #                           decay_steps=EPOCHS * (504 // BATCH_SIZE))
    if OPTIMIZER_NAME.lower() == 'adam':
        opt = Adam(learning_rate=LEARNING_RATE)
    elif OPTIMIZER_NAME.lower() == 'sgd':
        opt = SGD(learning_rate=LEARNING_RATE, momentum=0.9)
    elif OPTIMIZER_NAME.lower() == 'adamw':
        opt = AdamW(learning_rate=LEARNING_RATE)
    else:
        opt = RMSprop(learning_rate=LEARNING_RATE)

    model.compile(optimizer=opt, loss=tf.keras.losses.CategoricalFocalCrossentropy(label_smoothing=0.1, gamma=1.0), metrics=['accuracy'])
    # model.compile(optimizer=opt, loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1), metrics=['accuracy'])

    # Simpan model dengan nama berbeda tiap fold
    current_model_path = f'best_custom_cnn_uv_fold{fold_no}.keras'
    callbacks_list = [
        EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-6, verbose=1),
        ModelCheckpoint(current_model_path, monitor='val_accuracy', save_best_only=True, verbose=0)
    ]

    # --- C. TRAINING (Cell 5 Lama) ---
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=EPOCHS,
        callbacks=callbacks_list,
        # class_weight=fold_class_weights, 
        verbose=1
    )

    # =================================================================================================
    # 6. EVALUASI AKHIR PADA DATA TEST (KODE ASLI ANDA, TIDAK DIUBAH LOGIKANYA)
    # =================================================================================================
    print(f"\n[INFO] Melakukan Evaluasi Fold {fold_no}...")

    try:
        model.load_weights(current_model_path)
        print(f"✓ Model terbaik berhasil dimuat dari {current_model_path}")
    except:
        print("⚠️ Menggunakan bobot model epoch terakhir")

    Y_pred_probs = model.predict(test_ds, verbose=1)
    y_pred = np.argmax(Y_pred_probs, axis=1) 

    y_true_onehot = np.concatenate([y for x, y in test_ds], axis=0)
    y_true = np.argmax(y_true_onehot, axis=1)

    class_names = ['Kelas 1 (1 PPB)', 'Kelas 2 (2 PPB)', 'Kelas 3 (3 PPB)', 'Kelas 4 (4 PPB)']

    test_acc = accuracy_score(y_true, y_pred)
    global_accuracies.append(test_acc * 100)
    
    confidence_scores = np.max(Y_pred_probs, axis=1)
    avg_conf = np.mean(confidence_scores)

    report = classification_report(y_true, y_pred, target_names=class_names, digits=4, output_dict=True)
    print("\n" + "=" * 60)
    print(f"📋 CLASSIFICATION REPORT FOLD {fold_no}")
    print("=" * 60)
    print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

    cm = confusion_matrix(y_true, y_pred)
    cm_str = str(cm.tolist())

    plot_folder = "history_plots_customCNN" 
    if not os.path.exists(plot_folder):
        os.makedirs(plot_folder)

    current_time_str = datetime.now().strftime("%Y%m%d_%H%M%S")
    # Nama file disesuaikan agar fold tidak tertimpa
    plot_filename = f"{current_time_str}_Fold{fold_no}_CM_Acc{test_acc*100:.2f}.png" 
    plot_filepath = os.path.join(plot_folder, plot_filename)

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names, annot_kws={"size": 14})
    plt.title(f'Confusion Matrix Fold {fold_no} (Acc: {test_acc*100:.2f}%)')
    plt.ylabel('Actual Label', fontsize=12)
    plt.xlabel('Predicted Label', fontsize=12)
    plt.tight_layout()

    plt.savefig(plot_filepath, dpi=300, bbox_inches='tight')
    plt.close() # Ditutup agar tidak menumpuk di layar

    print(f"✅ Akurasi Fold {fold_no}: {test_acc*100:.2f}%")

    # =================================================================================================
    # 7. VISUALISASI HASIL PELATIHAN (KODE ASLI ANDA)
    # =================================================================================================
    plt.figure(figsize=(14, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    plt.title(f'Kurva Akurasi Fold {fold_no} (Acc: {test_acc*100:.2f}%)', fontsize=14)
    plt.xlabel('Epoch')
    plt.ylabel('Akurasi')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss (Error)', linewidth=2)
    plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    plt.title(f'Kurva Loss Fold {fold_no}', fontsize=14)
    plt.xlabel('Epoch')
    plt.ylabel('Loss (Categorical Crossentropy)')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)

    plt.tight_layout()

    folder_name = "visualizations_CUSTOM"
    if not os.path.exists(folder_name):
        os.makedirs(folder_name) 
    
    file_name = f"{current_time_str}_Fold{fold_no}_Acc{test_acc*100:.2f}.png"
    save_path = os.path.join(folder_name, file_name)

    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.close()

    # =================================================================================================
    # 8. SISTEM PENYIMPANAN LOG (KODE ASLI ANDA)
    # =================================================================================================
    LOG_FILE_PATH = "experiment_log_custom_cnn.csv"

    log_data = {
        "Timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
        "Fold_No": fold_no, # Tambahan untuk tracking fold
        "Model": "Custom CNN (Dual-Pooling UV)",
        "Total_Params": model.count_params(),
        "Learning_Rate": LEARNING_RATE,
        "Batch_Size": BATCH_SIZE, 
        "Dropout_Rate": DROPOUT_RATE,
        "Img_Size": IMG_SIZE,  
        "Use_Class_Weights": "Yes (Dynamic K-Fold)",
        "Accuracy": round(test_acc, 4),
        "Avg_Confidence": round(avg_conf, 4),
        "Confusion_Matrix": cm_str,
        "optimizer": OPTIMIZER_NAME  # Menyimpan nama optimizer yang digunakan
    }

    for idx, label in enumerate(class_names):
        metrics = report[label] 
        log_data[f"C{idx+1}_Prec"] = round(metrics['precision'], 4)
        log_data[f"C{idx+1}_Rec"] = round(metrics['recall'], 4)
        log_data[f"C{idx+1}_F1"] = round(metrics['f1-score'], 4)

    df_new_log = pd.DataFrame([log_data])

    if not os.path.exists(LOG_FILE_PATH):
        df_new_log.to_csv(LOG_FILE_PATH, index=False)
    else:
        df_new_log.to_csv(LOG_FILE_PATH, mode='a', header=False, index=False)
# Out:
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# 🚀 MEMULAI TRAINING FOLD KE-1
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Epoch 1/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 202ms/step - accuracy: 0.3317 - loss: 0.7914 - val_accuracy: 0.4176 - val_loss: 0.2588 - learning_rate: 5.0000e-04
# Epoch 2/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.3080 - loss: 0.3434 - val_accuracy: 0.4176 - val_loss: 0.2559 - learning_rate: 5.0000e-04
# Epoch 3/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.3716 - loss: 0.2746 - val_accuracy: 0.4176 - val_loss: 0.2527 - learning_rate: 5.0000e-04
# Epoch 4/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.4264 - loss: 0.2437 - val_accuracy: 0.4176 - val_loss: 0.2498 - learning_rate: 5.0000e-04
# Epoch 5/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.4364 - loss: 0.2329 - val_accuracy: 0.4176 - val_loss: 0.2533 - learning_rate: 5.0000e-04
# Epoch 6/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 12s 205ms/step - accuracy: 0.4464 - loss: 0.2253 - val_accuracy: 0.4066 - val_loss: 0.2462 - learning_rate: 5.0000e-04
# Epoch 7/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.4589 - loss: 0.2158 - val_accuracy: 0.3846 - val_loss: 0.2369 - learning_rate: 5.0000e-04
# Epoch 8/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.4813 - loss: 0.2117 - val_accuracy: 0.3791 - val_loss: 0.2376 - learning_rate: 5.0000e-04
# Epoch 9/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.4900 - loss: 0.2115 - val_accuracy: 0.4890 - val_loss: 0.2224 - learning_rate: 5.0000e-04
# Epoch 10/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.4900 - loss: 0.2053 - val_accuracy: 0.1319 - val_loss: 0.2712 - learning_rate: 5.0000e-04
# Epoch 11/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.
75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 194ms/step - accuracy: 0.6135 - loss: 0.1697 - val_accuracy: 0.6374 - val_loss: 0.1609 - learning_rate: 2.5000e-04
# Epoch 59/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.6309 - loss: 0.1636 - val_accuracy: 0.6319 - val_loss: 0.1589 - learning_rate: 2.5000e-04
# Epoch 60/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.6309 - loss: 0.1620 - val_accuracy: 0.6758 - val_loss: 0.1584 - learning_rate: 2.5000e-04
# Epoch 61/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.6397 - loss: 0.1611 - val_accuracy: 0.5879 - val_loss: 0.1679 - learning_rate: 2.5000e-04
# Epoch 62/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.6147 - loss: 0.1654 - val_accuracy: 0.5495 - val_loss: 0.1759 - learning_rate: 2.5000e-04
# Epoch 63/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 194ms/step - accuracy: 0.6209 - loss: 0.1642 - val_accuracy: 0.5604 - val_loss: 0.1736 - learning_rate: 2.5000e-04
# Epoch 64/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.6110 - loss: 0.1642 - val_accuracy: 0.6703 - val_loss: 0.1587 - learning_rate: 2.5000e-04
# Epoch 65/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.6122 - loss: 0.1669 - val_accuracy: 0.5824 - val_loss: 0.1646 - learning_rate: 2.5000e-04
# Epoch 66/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.6434 - loss: 0.1602 - val_accuracy: 0.5824 - val_loss: 0.1764 - learning_rate: 2.5000e-04
# Epoch 67/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.6284 - loss: 0.1619 - val_accuracy: 0.6374 - val_loss: 0.1705 - learning_rate: 2.5000e-04
# Epoch 68/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.6397 - loss: 0.1617 - val_accuracy: 0.6154 - val_loss: 0.1744 - learning_rate: 2.5000e-04
# Epoch 69/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.6359 - loss: 0.1626 - val_accuracy: 0.5055 - val_loss: 0.1954 - learning_rate: 2.5000e-04
# Epoch 70/75
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.6619 - loss: 0.1581
# Epoch 70: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.6384 - loss: 0.1620 - val_accuracy: 0.6374 - val_loss: 0.1608 - learning_rate: 2.5000e-04
# Epoch 71/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.6509 - loss: 0.1601 - val_accuracy: 0.6264 - val_loss: 0.1580 - learning_rate: 1.2500e-04
# Epoch 72/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.6384 - loss: 0.1613 - val_accuracy: 0.6648 - val_loss: 0.1583 - learning_rate: 1.2500e-04
# Epoch 73/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.6496 - loss: 0.1568 - val_accuracy: 0.6593 - val_loss: 0.1575 - learning_rate: 1.2500e-04
# Epoch 74/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.6384 - loss: 0.1597 - val_accuracy: 0.6154 - val_loss: 0.1682 - learning_rate: 1.2500e-04
# Epoch 75/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.6384 - loss: 0.1605 - val_accuracy: 0.6099 - val_loss: 0.1691 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 73.
#
# [INFO] Melakukan Evaluasi Fold 1...
# ✓ Model terbaik berhasil dimuat dari best_custom_cnn_uv_fold1.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step
#
# ============================================================
# 📋 CLASSIFICATION REPORT FOLD 1
# ============================================================
#                  precision    recall  f1-score   support
#
# Kelas 1 (1 PPB)     0.6818    0.7692    0.7229        39
# Kelas 2 (2 PPB)     0.6484    0.7763    0.7066        76
# Kelas 3 (3 PPB)     0.7500    0.4375    0.5526        48
# Kelas 4 (4 PPB)     0.6842    0.6842    0.6842        19
#
#        accuracy                         0.6758       182
#       macro avg     0.6911    0.6668    0.6666       182
#    weighted avg     0.6861    0.6758    0.6671       182
#
# ✅ Akurasi Fold 1: 67.58%
#
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.6085 - loss: 0.1761 - val_accuracy: 0.5714 - val_loss: 0.1738 - learning_rate: 5.0000e-04
# Epoch 48/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.6085 - loss: 0.1771 - val_accuracy: 0.5440 - val_loss: 0.1853 - learning_rate: 5.0000e-04
# Epoch 49/75
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.5749 - loss: 0.1766
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5985 - loss: 0.1708 - val_accuracy: 0.4670 - val_loss: 0.2144 - learning_rate: 5.0000e-04
# Epoch 50/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.6060 - loss: 0.1716 - val_accuracy: 0.5110 - val_loss: 0.1866 - learning_rate: 2.5000e-04
# Epoch 51/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.6309 - loss: 0.1688 - val_accuracy: 0.5769 - val_loss: 0.1924 - learning_rate: 2.5000e-04
# Epoch 52/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.6160 - loss: 0.1693 - val_accuracy: 0.5604 - val_loss: 0.1681 - learning_rate: 2.5000e-04
# Epoch 53/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.6284 - loss: 0.1671 - val_accuracy: 0.5440 - val_loss: 0.1890 - learning_rate: 2.5000e-04
# Epoch 54/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.6035 - loss: 0.1662 - val_accuracy: 0.6099 - val_loss: 0.1810 - learning_rate: 2.5000e-04
# Epoch 54: early stopping
# Restoring model weights from the end of the best epoch: 39.
#
# [INFO] Melakukan Evaluasi Fold 2...
# ✓ Model terbaik berhasil dimuat dari best_custom_cnn_uv_fold2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step
#
# ============================================================
# 📋 CLASSIFICATION REPORT FOLD 2
# ============================================================
#                  precision    recall  f1-score   support
#
# Kelas 1 (1 PPB)     0.7368    0.7179    0.7273        39
# Kelas 2 (2 PPB)     0.6842    0.6842    0.6842        76
# Kelas 3 (3 PPB)     0.5588    0.3958    0.4634        48
# Kelas 4 (4 PPB)     0.4118    0.7368    0.5283        19
#
#        accuracy                         0.6209       182
#       macro avg     0.5979    0.6337    0.6008       182
#    weighted avg     0.6340    0.6209    0.6189       182
#
# ✅ Akurasi Fold 2: 62.09%
#
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# 🚀 MEMULAI TRAINING FOLD KE-3
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Epoch 1/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 200ms/step - accuracy: 0.2768 - loss: 1.2763 - val_accuracy: 0.2637 - val_loss: 0.2638 - learning_rate: 5.0000e-04
# Epoch 2/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.2955 - loss: 0.3731 - val_accuracy: 0.2637 - val_loss: 0.2741 - learning_rate: 5.0000e-04
# Epoch 3/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.3441 - loss: 0.2828 - val_accuracy: 0.2308 - val_loss: 0.2775 - learning_rate: 5.0000e-04
# Epoch 4/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.3890 - loss: 0.2551 - val_accuracy: 0.2637 - val_loss: 0.2664 - learning_rate: 5.0000e-04
# Epoch 5/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.4426 - loss: 0.2371 - val_accuracy: 0.2857 - val_loss: 0.2587 - learning_rate: 5.0000e-04
# Epoch 6/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.4501 - loss: 0.2275 - val_accuracy: 0.1648 - val_loss: 0.2612 - learning_rate: 5.0000e-04
# Epoch 7/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.4626 - loss: 0.2213 - val_accuracy: 0.4890 - val_loss: 0.2342 - learning_rate: 5.0000e-04
# Epoch 8/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.4701 - loss: 0.2170 - val_accuracy: 0.5495 - val_loss: 0.2282 - learning_rate: 5.0000e-04
# Epoch 9/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.4464 - loss: 0.2146 - val_accuracy: 0.2527 - val_loss: 0.2267 - learning_rate: 5.0000e-04
# Epoch 10/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.5012 - loss: 0.2030 - val_accuracy: 0.3407 - val_loss: 0.2209 - learning_rate: 5.0000e-04
# Epoch 11/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.4601 - loss: 0.2095 - val_accuracy: 0.5934 - val_loss: 0.2010 - learning_rate: 5.0000e-04
# Epoch 12/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5162 - loss: 0.2062 - val_accuracy: 0.2967 - val_loss: 0.2567 - learning_rate: 5.0000e-04
# Epoch 13/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.4838 - loss: 0.2111 - val_accuracy: 0.5110 - val_loss: 0.1950 - learning_rate: 5.0000e-04
# Epoch 14/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5137 - loss: 0.2013 - val_accuracy: 0.5549 - val_loss: 0.1932 - learning_rate: 5.0000e-04
# Epoch 15/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.5187 - loss: 0.1950 - val_accuracy: 0.5714 - val_loss: 0.1822 - learning_rate: 5.0000e-04
# Epoch 16/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5162 - loss: 0.1950 - val_accuracy: 0.2857 - val_loss: 0.3056 - learning_rate: 5.0000e-04
# Epoch 17/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5349 - loss: 0.1919 - val_accuracy: 0.6209 - val_loss: 0.1772 - learning_rate: 5.0000e-04
# Epoch 18/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5549 - loss: 0.1907 - val_accuracy: 0.4780 - val_loss: 0.2122 - learning_rate: 5.0000e-04
# Epoch 19/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5187 - loss: 0.1912 - val_accuracy: 0.5000 - val_loss: 0.2065 - learning_rate: 5.0000e-04
# Epoch 20/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5636 - loss: 0.1896 - val_accuracy: 0.2912 - val_loss: 0.2514 - learning_rate: 5.0000e-04
# Epoch 21/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.5599 - loss: 0.1904 - val_accuracy: 0.3736 - val_loss: 0.2283 - learning_rate: 5.0000e-04
# Epoch 22/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.5324 - loss: 0.1920 - val_accuracy: 0.5824 - val_loss: 0.1758 - learning_rate: 5.0000e-04
# Epoch 23/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5499 - loss: 0.1889 - val_accuracy: 0.4560 - val_loss: 0.2134 - learning_rate: 5.0000e-04
# Epoch 24/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.5274 - loss: 0.1927 - val_accuracy: 0.2418 - val_loss: 0.3185 - learning_rate: 5.0000e-04
# Epoch 25/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.5786 - loss: 0.1868 - val_accuracy: 0.6374 - val_loss: 0.1679 - learning_rate: 5.0000e-04
# Epoch 26/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5586 - loss: 0.1859 - val_accuracy: 0.5275 - val_loss: 0.2003 - learning_rate: 5.0000e-04
# Epoch 27/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.5798 - loss: 0.1813 - val_accuracy: 0.3956 - val_loss: 0.2352 - learning_rate: 5.0000e-04
# Epoch 28/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5723 - loss: 0.1852 - val_accuracy: 0.5220 - val_loss: 0.1940 - learning_rate: 5.0000e-04
# Epoch 29/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5611 - loss: 0.1867 - val_accuracy: 0.5659 - val_loss: 0.1843 - learning_rate: 5.0000e-04
# Epoch 30/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5761 - loss: 0.1862 - val_accuracy: 0.5549 - val_loss: 0.1819 - learning_rate: 5.0000e-04
# Epoch 31/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.5723 - loss: 0.1819 - val_accuracy: 0.5275 - val_loss: 0.2051 - learning_rate: 5.0000e-04
# Epoch 32/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5362 - loss: 0.1837 - val_accuracy: 0.6429 - val_loss: 0.1744 - learning_rate: 5.0000e-04
# Epoch 33/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5860 - loss: 0.1808 - val_accuracy: 0.5934 - val_loss: 0.1674 - learning_rate: 5.0000e-04
# Epoch 34/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5898 - loss: 0.1780 - val_accuracy: 0.6154 - val_loss: 0.1725 - learning_rate: 5.0000e-04
# Epoch 35/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5698 - loss: 0.1806 - val_accuracy: 0.5440 - val_loss: 0.1907 - learning_rate: 5.0000e-04
# Epoch 36/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.5761 - loss: 0.1820 - val_accuracy: 0.6538 - val_loss: 0.1631 - learning_rate: 5.0000e-04
# Epoch 37/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5623 - loss: 0.1822 - val_accuracy: 0.5330 - val_loss: 0.1924 - learning_rate: 5.0000e-04
# Epoch 38/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.5748 - loss: 0.1764 - val_accuracy: 0.5165 - val_loss: 0.2002 - learning_rate: 5.0000e-04
# Epoch 39/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5873 - loss: 0.1784 - val_accuracy: 0.4396 - val_loss: 0.2260 - learning_rate: 5.0000e-04
# Epoch 40/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5761 - loss: 0.1779 - val_accuracy: 0.6429 - val_loss: 0.1682 - learning_rate: 5.0000e-04
# Epoch 41/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5948 - loss: 0.1762 - val_accuracy: 0.5769 - val_loss: 0.1689 - learning_rate: 5.0000e-04
# Epoch 42/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5810 - loss: 0.1779 - val_accuracy: 0.5165 - val_loss: 0.1995 - learning_rate: 5.0000e-04
# Epoch 43/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.6110 - loss: 0.1753 - val_accuracy: 0.5989 - val_loss: 0.1736 - learning_rate: 5.0000e-04
# Epoch 44/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.6085 - loss: 0.1759 - val_accuracy: 0.6044 - val_loss: 0.1756 - learning_rate: 5.0000e-04
# Epoch 45/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5973 - loss: 0.1777 - val_accuracy: 0.5989 - val_loss: 0.1772 - learning_rate: 5.0000e-04
# Epoch 46/75
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.5771 - loss: 0.1763
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5748 - loss: 0.1799 - val_accuracy: 0.5989 - val_loss: 0.1740 - learning_rate: 5.0000e-04
# Epoch 47/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5998 - loss: 0.1761 - val_accuracy: 0.6099 - val_loss: 0.1797 - learning_rate: 2.5000e-04
# Epoch 48/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.6272 - loss: 0.1689 - val_accuracy: 0.6538 - val_loss: 0.1686 - learning_rate: 2.5000e-04
# Epoch 49/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.6147 - loss: 0.1659 - val_accuracy: 0.4451 - val_loss: 0.2237 - learning_rate: 2.5000e-04
# Epoch 50/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.5985 - loss: 0.1692 - val_accuracy: 0.5549 - val_loss: 0.1810 - learning_rate: 2.5000e-04
# Epoch 51/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.6010 - loss: 0.1726 - val_accuracy: 0.6044 - val_loss: 0.1719 - learning_rate: 2.5000e-04
# Epoch 51: early stopping
# Restoring model weights from the end of the best epoch: 36.
#
# [INFO] Melakukan Evaluasi Fold 3...
# ✓ Model terbaik berhasil dimuat dari best_custom_cnn_uv_fold3.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step
#
# ============================================================
# 📋 CLASSIFICATION REPORT FOLD 3
# ============================================================
#                  precision    recall  f1-score   support
#
# Kelas 1 (1 PPB)     0.7333    0.8462    0.7857        39
# Kelas 2 (2 PPB)     0.7083    0.6711    0.6892        76
# Kelas 3 (3 PPB)     0.5088    0.6042    0.5524        48
# Kelas 4 (4 PPB)     0.7500    0.3158    0.4444        19
#
#        accuracy                         0.6538       182
#       macro avg     0.6751    0.6093    0.6179       182
#    weighted avg     0.6654    0.6538    0.6482       182
#
# ✅ Akurasi Fold 3: 65.38%
#
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# 🚀 MEMULAI TRAINING FOLD KE-4
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Epoch 1/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 200ms/step - accuracy: 0.2852 - loss: 0.7926 - val_accuracy: 0.2155 - val_loss: 0.2612 - learning_rate: 5.0000e-04
# Epoch 2/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.3200 - loss: 0.3390 - val_accuracy: 0.2155 - val_loss: 0.2546 - learning_rate: 5.0000e-04
# Epoch 3/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.3549 - loss: 0.2805 - val_accuracy: 0.2210 - val_loss: 0.2559 - learning_rate: 5.0000e-04
# Epoch 4/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.4271 - loss: 0.2390 - val_accuracy: 0.2652 - val_loss: 0.2555 - learning_rate: 5.0000e-04
# Epoch 5/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.4471 - loss: 0.2330 - val_accuracy: 0.2928 - val_loss: 0.2481 - learning_rate: 5.0000e-04
# Epoch 6/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.4471 - loss: 0.2281 - val_accuracy: 0.2762 - val_loss: 0.2504 - learning_rate: 5.0000e-04
# Epoch 7/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.4695 - loss: 0.2198 - val_accuracy: 0.2818 - val_loss: 0.2450 - learning_rate: 5.0000e-04
# Epoch 8/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.4720 - loss: 0.2168 - val_accuracy: 0.1989 - val_loss: 0.2511 - learning_rate: 5.0000e-04
# Epoch 9/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.4670 - loss: 0.2124 - val_accuracy: 0.4807 - val_loss: 0.2266 - learning_rate: 5.0000e-04
# Epoch 10/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.4956 - loss: 0.2062 - val_accuracy: 0.5193 - val_loss: 0.2104 - learning_rate: 5.0000e-04
# Epoch 11/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 195ms/step - accuracy: 0.5168 - loss: 0.1944 - val_accuracy: 0.2210 - val_loss: 0.2560 - learning_rate: 5.0000e-04
# Epoch 12/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5243 - loss: 0.1986 - val_accuracy: 0.2762 - val_loss: 0.2523 - learning_rate: 5.0000e-04
# Epoch 13/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.5318 - loss: 0.1950 - val_accuracy: 0.3315 - val_loss: 0.2378 - learning_rate: 5.0000e-04
# Epoch 14/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5255 - loss: 0.1929 - val_accuracy: 0.5083 - val_loss: 0.1921 - learning_rate: 5.0000e-04
# Epoch 15/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5218 - loss: 0.1954 - val_accuracy: 0.2486 - val_loss: 0.3651 - learning_rate: 5.0000e-04
# Epoch 16/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5305 - loss: 0.1966 - val_accuracy: 0.5138 - val_loss: 0.1934 - learning_rate: 5.0000e-04
# Epoch 17/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.5517 - loss: 0.1989 - val_accuracy: 0.5746 - val_loss: 0.1771 - learning_rate: 5.0000e-04
# Epoch 18/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 12s 204ms/step - accuracy: 0.5629 - loss: 0.1910 - val_accuracy: 0.3370 - val_loss: 0.2547 - learning_rate: 5.0000e-04
# Epoch 19/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 12s 202ms/step - accuracy: 0.5355 - loss: 0.1896 - val_accuracy: 0.5249 - val_loss: 0.2001 - learning_rate: 5.0000e-04
# Epoch 20/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 12s 203ms/step - accuracy: 0.5467 - loss: 0.1892 - val_accuracy: 0.2265 - val_loss: 0.4426 - learning_rate: 5.0000e-04
# Epoch 21/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 12s
75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.6314 - loss: 0.1592 - val_accuracy: 0.6077 - val_loss: 0.1714 - learning_rate: 6.2500e-05
# Epoch 65/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.6289 - loss: 0.1630 - val_accuracy: 0.6409 - val_loss: 0.1651 - learning_rate: 6.2500e-05
# Epoch 66/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.6376 - loss: 0.1589 - val_accuracy: 0.6354 - val_loss: 0.1658 - learning_rate: 6.2500e-05
# Epoch 66: early stopping
# Restoring model weights from the end of the best epoch: 51.
#
# [INFO] Melakukan Evaluasi Fold 4...
# ✓ Model terbaik berhasil dimuat dari best_custom_cnn_uv_fold4.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step
#
# ============================================================
# 📋 CLASSIFICATION REPORT FOLD 4
# ============================================================
#                  precision    recall  f1-score   support
#
# Kelas 1 (1 PPB)     0.7179    0.7179    0.7179        39
# Kelas 2 (2 PPB)     0.6374    0.7632    0.6946        76
# Kelas 3 (3 PPB)     0.6389    0.4894    0.5542        47
# Kelas 4 (4 PPB)     0.6667    0.5263    0.5882        19
#
#        accuracy                         0.6575       181
#       macro avg     0.6652    0.6242    0.6388       181
#    weighted avg     0.6582    0.6575    0.6520       181
#
# ✅ Akurasi Fold 4: 65.75%
#
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# 🚀 MEMULAI TRAINING FOLD KE-5
# ★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★★
# Epoch 1/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 202ms/step - accuracy: 0.2951 - loss: 0.8283 - val_accuracy: 0.2818 - val_loss: 0.2530 - learning_rate: 5.0000e-04
# Epoch 2/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.3462 - loss: 0.3237 - val_accuracy: 0.4144 - val_loss: 0.2471 - learning_rate: 5.0000e-04
# Epoch 3/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.3599 - loss: 0.2744 - val_accuracy: 0.4088 - val_loss: 0.2455 - learning_rate: 5.0000e-04
# Epoch 4/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.3960 - loss: 0.2429 - val_accuracy: 0.4144 - val_loss: 0.2478 - learning_rate: 5.0000e-04
# Epoch 5/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.4608 - loss: 0.2287 - val_accuracy: 0.4144 - val_loss: 0.2426 - learning_rate: 5.0000e-04
# Epoch 6/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.4570 - loss: 0.2215 - val_accuracy: 0.4199 - val_loss: 0.2374 - learning_rate: 5.0000e-04
# Epoch 7/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.4583 - loss: 0.2170 - val_accuracy: 0.4807 - val_loss: 0.2366 - learning_rate: 5.0000e-04
# Epoch 8/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.4882 - loss: 0.2073 - val_accuracy: 0.4309 - val_loss: 0.2347 - learning_rate: 5.0000e-04
# Epoch 9/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.4932 - loss: 0.2074 - val_accuracy: 0.3260 - val_loss: 0.2378 - learning_rate: 5.0000e-04
# Epoch 10/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5131 - loss: 0.2071 - val_accuracy: 0.3757 - val_loss: 0.2316 - learning_rate: 5.0000e-04
# Epoch 11/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.5068 - loss: 0.2027 - val_accuracy: 0.2486 - val_loss: 0.2626 - learning_rate: 5.0000e-04
# Epoch 12/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.5156 - loss: 0.1959 - val_accuracy: 0.5304 - val_loss: 0.1963 - learning_rate: 5.0000e-04
# Epoch 13/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5081 - loss: 0.1975 - val_accuracy: 0.2652 - val_loss: 0.2394 - learning_rate: 5.0000e-04
# Epoch 14/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5230 - loss: 0.1937 - val_accuracy: 0.4862 - val_loss: 0.2327 - learning_rate: 5.0000e-04
# Epoch 15/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5031 - loss: 0.2002 - val_accuracy: 0.4807 - val_loss: 0.2008 - learning_rate: 5.0000e-04
# Epoch 16/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.5156 - loss: 0.1901 - val_accuracy: 0.4365 - val_loss: 0.2178 - learning_rate: 5.0000e-04
# Epoch 17/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 200ms/step - accuracy: 0.5168 - loss: 0.1895 - val_accuracy: 0.5414 - val_loss: 0.1837 - learning_rate: 5.0000e-04
# Epoch 18/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.5430 - loss: 0.1941 - val_accuracy: 0.4751 - val_loss: 0.2014 - learning_rate: 5.0000e-04
# Epoch 19/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 199ms/step - accuracy: 0.5467 - loss: 0.1918 - val_accuracy: 0.5083 - val_loss: 0.2060 - learning_rate: 5.0000e-04
# Epoch 20/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 199ms/step - accuracy: 0.5205 - loss: 0.1906 - val_accuracy: 0.5691 - val_loss: 0.1865 - learning_rate: 5.0000e-04
# Epoch 21/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.5293 - loss: 0.1930 - val_accuracy: 0.4696 - val_loss: 0.2091 - learning_rate: 5.0000e-04
# Epoch 22/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 199ms/step - accuracy: 0.5641 - loss: 0.1855 - val_accuracy: 0.2376 - val_loss: 0.3608 - learning_rate: 5.0000e-04
# Epoch 23/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.5280 - loss: 0.1884 - val_accuracy: 0.5856 - val_loss: 0.1871 - learning_rate: 5.0000e-04
# Epoch 24/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.5704 - loss: 0.1837 - val_accuracy: 0.4917 - val_loss: 0.2003 - learning_rate: 5.0000e-04
# Epoch 25/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.5666 - loss: 0.1848 - val_accuracy: 0.2762 - val_loss: 0.3286 - learning_rate: 5.0000e-04
# Epoch 26/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.5579 - loss: 0.1881 - val_accuracy: 0.5359 - val_loss: 0.1851 - learning_rate: 5.0000e-04
# Epoch 27/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.5592 - loss: 0.1841 - val_accuracy: 0.5525 - val_loss: 0.1768 - learning_rate: 5.0000e-04
# Epoch 28/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.5778 - loss: 0.1834 - val_accuracy: 0.5414 - val_loss: 0.2003 - learning_rate: 5.0000e-04
# Epoch 29/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.5704 - loss: 0.1817 - val_accuracy: 0.5138 - val_loss: 0.2002 - learning_rate: 5.0000e-04
# Epoch 30/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.5504 - loss: 0.1835 - val_accuracy: 0.5470 - val_loss: 0.1795 - learning_rate: 5.0000e-04
# Epoch 31/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5604 - loss: 0.1847 - val_accuracy: 0.5580 - val_loss: 0.1774 - learning_rate: 5.0000e-04
# Epoch 32/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.5791 - loss: 0.1832 - val_accuracy: 0.3702 - val_loss: 0.2261 - learning_rate: 5.0000e-04
# Epoch 33/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.5529 - loss: 0.1843 - val_accuracy: 0.4972 - val_loss: 0.1961 - learning_rate: 5.0000e-04
# Epoch 34/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5866 - loss: 0.1786 - val_accuracy: 0.3094 - val_loss: 0.2824 - learning_rate: 5.0000e-04
# Epoch 35/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5828 - loss: 0.1795 - val_accuracy: 0.5414 - val_loss: 0.2011 - learning_rate: 5.0000e-04
# Epoch 36/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5965 - loss: 0.1784 - val_accuracy: 0.5083 - val_loss: 0.2030 - learning_rate: 5.0000e-04
# Epoch 37/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.5853 - loss: 0.1839 - val_accuracy: 0.5967 - val_loss: 0.1732 - learning_rate: 5.0000e-04
# Epoch 38/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.5479 - loss: 0.1832 - val_accuracy: 0.4530 - val_loss: 0.2164 - learning_rate: 5.0000e-04
# Epoch 39/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5878 - loss: 0.1797 - val_accuracy: 0.1768 - val_loss: 0.3928 - learning_rate: 5.0000e-04
# Epoch 40/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.6052 - loss: 0.1763 - val_accuracy: 0.5912 - val_loss: 0.1785 - learning_rate: 5.0000e-04
# Epoch 41/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.5704 - loss: 0.1792 - val_accuracy: 0.5856 - val_loss: 0.1727 - learning_rate: 5.0000e-04
# Epoch 42/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.6002 - loss: 0.1738 - val_accuracy: 0.5083 - val_loss: 0.1957 - learning_rate: 5.0000e-04
# Epoch 43/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5940 - loss: 0.1756 - val_accuracy: 0.4033 - val_loss: 0.2207 - learning_rate: 5.0000e-04
# Epoch 44/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5716 - loss: 0.1764 - val_accuracy: 0.5414 - val_loss: 0.1872 - learning_rate: 5.0000e-04
# Epoch 45/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.5940 - loss: 0.1739 - val_accuracy: 0.2376 - val_loss: 0.3420 - learning_rate: 5.0000e-04
# Epoch 46/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.6015 - loss: 0.1790 - val_accuracy: 0.3536 - val_loss: 0.2354 - learning_rate: 5.0000e-04
# Epoch 47/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.6015 - loss: 0.1797 - val_accuracy: 0.6077 - val_loss: 0.1768 - learning_rate: 5.0000e-04
# Epoch 48/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.6015 - loss: 0.1768 - val_accuracy: 0.5967 - val_loss: 0.1763 - learning_rate: 5.0000e-04
# Epoch 49/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5741 - loss: 0.1774 - val_accuracy: 0.5414 - val_loss: 0.1940 - learning_rate: 5.0000e-04
# Epoch 50/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5978 - loss: 0.1750 - val_accuracy: 0.5746 - val_loss: 0.1871 - learning_rate: 5.0000e-04
# Epoch 51/75
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.5899 - loss: 0.1708
# Epoch 51: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.5990 - loss: 0.1722 - val_accuracy: 0.5470 - val_loss: 0.1832 - learning_rate: 5.0000e-04
# Epoch 52/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.6164 - loss: 0.1687 - val_accuracy: 0.5746 - val_loss: 0.1729 - learning_rate: 2.5000e-04
# Epoch 53/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.6177 - loss: 0.1642 - val_accuracy: 0.5746 - val_loss: 0.1793 - learning_rate: 2.5000e-04
# Epoch 54/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.5878 - loss: 0.1730 - val_accuracy: 0.5746 - val_loss: 0.1919 - learning_rate: 2.5000e-04
# Epoch 55/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.6177 - loss: 0.1689 - val_accuracy: 0.5856 - val_loss: 0.1692 - learning_rate: 2.5000e-04
# Epoch 56/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.6314 - loss: 0.1640 - val_accuracy: 0.5967 - val_loss: 0.1714 - learning_rate: 2.5000e-04
# Epoch 57/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.6164 - loss: 0.1678 - val_accuracy: 0.4862 - val_loss: 0.2016 - learning_rate: 2.5000e-04
# Epoch 58/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.6115 - loss: 0.1690 - val_accuracy: 0.5801 - val_loss: 0.1716 - learning_rate: 2.5000e-04
# Epoch 59/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.6351 - loss: 0.1685 - val_accuracy: 0.5967 - val_loss: 0.1767 - learning_rate: 2.5000e-04
# Epoch 60/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.6139 - loss: 0.1714 - val_accuracy: 0.5801 - val_loss: 0.1764 - learning_rate: 2.5000e-04
# Epoch 61/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.6090 - loss: 0.1701 - val_accuracy: 0.4917 - val_loss: 0.1990 - learning_rate: 2.5000e-04
# Epoch 62/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.6389 - loss: 0.1674 - val_accuracy: 0.5746 - val_loss: 0.1717 - learning_rate: 2.5000e-04
# Epoch 63/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.6239 - loss: 0.1654 - val_accuracy: 0.5580 - val_loss: 0.1812 - learning_rate: 2.5000e-04
# Epoch 64/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.6326 - loss: 0.1629 - val_accuracy: 0.5691 - val_loss: 0.1868 - learning_rate: 2.5000e-04
# Epoch 65/75
# 50/51 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.6458 - loss: 0.1709
# Epoch 65: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.6463 - loss: 0.1658 - val_accuracy: 0.6298 - val_loss: 0.1742 - learning_rate: 2.5000e-04
# Epoch 66/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.6538 - loss: 0.1649 - val_accuracy: 0.5635 - val_loss: 0.1734 - learning_rate: 1.2500e-04
# Epoch 67/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.6413 - loss: 0.1632 - val_accuracy: 0.5746 - val_loss: 0.1693 - learning_rate: 1.2500e-04
# Epoch 68/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.6351 - loss: 0.1646 - val_accuracy: 0.6188 - val_loss: 0.1702 - learning_rate: 1.2500e-04
# Epoch 69/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.6252 - loss: 0.1620 - val_accuracy: 0.6022 - val_loss: 0.1683 - learning_rate: 1.2500e-04
# Epoch 70/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.6476 - loss: 0.1632 - val_accuracy: 0.5801 - val_loss: 0.1815 - learning_rate: 1.2500e-04
# Epoch 71/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.6376 - loss: 0.1578 - val_accuracy: 0.5967 - val_loss: 0.1674 - learning_rate: 1.2500e-04
# Epoch 72/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.6426 - loss: 0.1616 - val_accuracy: 0.6298 - val_loss: 0.1693 - learning_rate: 1.2500e-04
# Epoch 73/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.6687 - loss: 0.1629 - val_accuracy: 0.6354 - val_loss: 0.1692 - learning_rate: 1.2500e-04
# Epoch 74/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.6314 - loss: 0.1658 - val_accuracy: 0.6133 - val_loss: 0.1692 - learning_rate: 1.2500e-04
# Epoch 75/75
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 11s 197ms/step - accuracy: 0.6538 - loss: 0.1588 - val_accuracy: 0.5912 - val_loss: 0.1693 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 71.
#
# [INFO] Melakukan Evaluasi Fold 5...
# ✓ Model terbaik berhasil dimuat dari best_custom_cnn_uv_fold5.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step
#
# ============================================================
# 📋 CLASSIFICATION REPORT FOLD 5
# ============================================================
#                  precision    recall  f1-score   support
#
# Kelas 1 (1 PPB)     0.7250    0.7436    0.7342        39
# Kelas 2 (2 PPB)     0.6222    0.7467    0.6788        75
# Kelas 3 (3 PPB)     0.5652    0.5417    0.5532        48
# Kelas 4 (4 PPB)     0.8000    0.2105    0.3333        19
#
#        accuracy                         0.6354       181
#       macro avg     0.6781    0.5606    0.5749       181
#    weighted avg     0.6479    0.6354    0.6212       181
#
# ✅ Akurasi Fold 5: 63.54%

# %%
# --- REKAPITULASI AKHIR K-FOLD ---
print("\n" + "="*60)
print("🏆 KESIMPULAN HASIL 5-FOLD CROSS VALIDATION")
print("="*60)
for i, acc in enumerate(global_accuracies):
    print(f"Fold {i+1}: {acc:.2f}%")
print("-" * 30)
print(f"RATA-RATA AKURASI KESELURUHAN: {np.mean(global_accuracies):.2f}% (+/- {np.std(global_accuracies):.2f}%)")
print("="*60)
# Out:
# ============================================================
# 🏆 KESIMPULAN HASIL 5-FOLD CROSS VALIDATION
# ============================================================
# Fold 1: 67.58%
# Fold 2: 62.09%
# Fold 3: 65.38%
# Fold 4: 65.75%
# Fold 5: 63.54%
# ------------------------------
# RATA-RATA AKURASI KESELURUHAN: 64.87% (+/- 1.89%)
# ============================================================

# %%
# # MULAI PERULANGAN K-FOLD (BAGIAN 4, 5, 6, 7, 8 MASUK KE DALAM SINI)

# skf = StratifiedKFold(n_splits=K_FOLDS, shuffle=True, random_state=42)
# global_accuracies = []

# for fold_no, (train_index, val_index) in enumerate(skf.split(X, y), 1):
#     print("\n" + "★"*60)
#     print(f"🚀 MEMULAI TRAINING FOLD KE-{fold_no}")
#     print("★"*60)
    
#     # --- A. SETUP DATA UNTUK FOLD INI ---
#     X_train_paths, X_val_paths = X[train_index], X[val_index]
#     y_train_labels, y_val_labels = y[train_index], y[val_index]
    
#     # ==============================================================================
#     # --- TAMBAHAN BARU: OVERSAMPLING ON-THE-FLY (KHUSUS DATA LATIH) ---
#     # ==============================================================================
#     # Asumsi: y adalah label One-Hot Encoding (misal Kelas 4 adalah indeks ke-3)
#     # 1. Cari indeks array yang merupakan Kelas 4
#     class_4_indices = np.where(y_train_labels == 3)[0]
    
#     # 2. Ekstrak path dan label untuk Kelas 4 tersebut
#     X_train_class_4 = X_train_paths[class_4_indices]
#     y_train_class_4 = y_train_labels[class_4_indices]
    
#     # 3. Kloning/Duplikasi dengan menggabungkan ke data asli (Menjadi tepat 2x lipat)
#     X_train_paths = np.concatenate([X_train_paths, X_train_class_4])
#     y_train_labels = np.concatenate([y_train_labels, y_train_class_4])
    
#     # 4. Acak (Shuffle) array agar data kloningan tidak menumpuk di akhir antrean
#     shuffle_idx = np.random.permutation(len(X_train_paths))
#     X_train_paths = X_train_paths[shuffle_idx]
#     y_train_labels = y_train_labels[shuffle_idx]
#     # ==============================================================================

#     # Hitung Bobot Kelas Otomatis untuk Fold ini
#     # Karena y_train_labels berupa One-Hot, kita ubah ke 1D (integer) agar sklearn tidak error
#     weights = class_weight.compute_class_weight('balanced', classes=np.unique(y_train_labels), y=y_train_labels)
#     fold_class_weights = dict(enumerate(weights))
    
#     # Buat Dataset
#     train_ds = tf.data.Dataset.from_tensor_slices((X_train_paths, y_train_labels))
# # ... (LANJUTKAN KE KODE ASLI ANDA MULAI DARI SINI: train_ds = train_ds.map(process_path, ...))
#     train_ds = train_ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)
#     train_ds = train_ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)
#     train_ds = train_ds.shuffle(len(X_train_paths)).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    
#     val_ds = tf.data.Dataset.from_tensor_slices((X_val_paths, y_val_labels))
#     val_ds = val_ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)
#     val_ds = val_ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    
#     # Aliasing val_ds menjadi test_ds agar kode evaluasi Anda di bawah tidak error
#     test_ds = val_ds 
    
#     # --- B. RESET & COMPILE MODEL (Cell 4 Lama) ---
#     tf.keras.backend.clear_session()
#     model = build_aflatoxin_uv_cnn()
    
#     # lr_schedule = CosineDecay(initial_learning_rate=0.0005, #lr paling stabil
#     #                           decay_steps=EPOCHS * (504 // BATCH_SIZE))
#     if OPTIMIZER_NAME.lower() == 'adam':
#         opt = Adam(learning_rate=LEARNING_RATE)
#     elif OPTIMIZER_NAME.lower() == 'sgd':
#         opt = SGD(learning_rate=LEARNING_RATE, momentum=0.9)
#     elif OPTIMIZER_NAME.lower() == 'adamw':
#         opt = AdamW(learning_rate=LEARNING_RATE)
#     else:
#         opt = RMSprop(learning_rate=LEARNING_RATE)

#     # model.compile(optimizer=opt, loss=tf.keras.losses.CategoricalFocalCrossentropy(label_smoothing=0.1, gamma=2.0), metrics=['accuracy'])
#     model.compile(optimizer=opt, loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1), metrics=['accuracy'])

#     # Simpan model dengan nama berbeda tiap fold
#     current_model_path = f'best_custom_cnn_uv_fold{fold_no}.keras'
#     callbacks_list = [
#         EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True, verbose=1),
#         ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-6, verbose=1),
#         ModelCheckpoint(current_model_path, monitor='val_accuracy', save_best_only=True, verbose=0)
#     ]

#     # --- C. TRAINING (Cell 5 Lama) ---
#     history = model.fit(
#         train_ds,
#         validation_data=val_ds,
#         epochs=EPOCHS,
#         callbacks=callbacks_list,
#         class_weight=fold_class_weights, 
#         verbose=1
#     )

#     # =================================================================================================
#     # 6. EVALUASI AKHIR PADA DATA TEST (KODE ASLI ANDA, TIDAK DIUBAH LOGIKANYA)
#     # =================================================================================================
#     print(f"\n[INFO] Melakukan Evaluasi Fold {fold_no}...")

#     try:
#         model.load_weights(current_model_path)
#         print(f"✓ Model terbaik berhasil dimuat dari {current_model_path}")
#     except:
#         print("⚠️ Menggunakan bobot model epoch terakhir")

#     Y_pred_probs = model.predict(test_ds, verbose=1)
#     y_pred = np.argmax(Y_pred_probs, axis=1) 

#     y_true_onehot = np.concatenate([y for x, y in test_ds], axis=0)
#     y_true = np.argmax(y_true_onehot, axis=1)

#     class_names = ['Kelas 1 (1 PPB)', 'Kelas 2 (2 PPB)', 'Kelas 3 (3 PPB)', 'Kelas 4 (4 PPB)']

#     test_acc = accuracy_score(y_true, y_pred)
#     global_accuracies.append(test_acc * 100)
    
#     confidence_scores = np.max(Y_pred_probs, axis=1)
#     avg_conf = np.mean(confidence_scores)

#     report = classification_report(y_true, y_pred, target_names=class_names, digits=4, output_dict=True)
#     print("\n" + "=" * 60)
#     print(f"📋 CLASSIFICATION REPORT FOLD {fold_no}")
#     print("=" * 60)
#     print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

#     cm = confusion_matrix(y_true, y_pred)
#     cm_str = str(cm.tolist())

#     plot_folder = "history_plots_customCNN" 
#     if not os.path.exists(plot_folder):
#         os.makedirs(plot_folder)

#     current_time_str = datetime.now().strftime("%Y%m%d_%H%M%S")
#     # Nama file disesuaikan agar fold tidak tertimpa
#     plot_filename = f"{current_time_str}_Fold{fold_no}_CM_Acc{test_acc*100:.2f}.png" 
#     plot_filepath = os.path.join(plot_folder, plot_filename)

#     plt.figure(figsize=(8, 6))
#     sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
#                 xticklabels=class_names, yticklabels=class_names, annot_kws={"size": 14})
#     plt.title(f'Confusion Matrix Fold {fold_no} (Acc: {test_acc*100:.2f}%)')
#     plt.ylabel('Actual Label', fontsize=12)
#     plt.xlabel('Predicted Label', fontsize=12)
#     plt.tight_layout()

#     plt.savefig(plot_filepath, dpi=300, bbox_inches='tight')
#     plt.close() # Ditutup agar tidak menumpuk di layar

#     print(f"✅ Akurasi Fold {fold_no}: {test_acc*100:.2f}%")

#     # =================================================================================================
#     # 7. VISUALISASI HASIL PELATIHAN (KODE ASLI ANDA)
#     # =================================================================================================
#     plt.figure(figsize=(14, 5))

#     plt.subplot(1, 2, 1)
#     plt.plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
#     plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
#     plt.title(f'Kurva Akurasi Fold {fold_no} (Acc: {test_acc*100:.2f}%)', fontsize=14)
#     plt.xlabel('Epoch')
#     plt.ylabel('Akurasi')
#     plt.legend()
#     plt.grid(True, linestyle='--', alpha=0.7)

#     plt.subplot(1, 2, 2)
#     plt.plot(history.history['loss'], label='Train Loss (Error)', linewidth=2)
#     plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
#     plt.title(f'Kurva Loss Fold {fold_no}', fontsize=14)
#     plt.xlabel('Epoch')
#     plt.ylabel('Loss (Categorical Crossentropy)')
#     plt.legend()
#     plt.grid(True, linestyle='--', alpha=0.7)

#     plt.tight_layout()

#     folder_name = "visualizations_CUSTOM"
#     if not os.path.exists(folder_name):
#         os.makedirs(folder_name) 
    
#     file_name = f"{current_time_str}_Fold{fold_no}_Acc{test_acc*100:.2f}.png"
#     save_path = os.path.join(folder_name, file_name)

#     plt.savefig(save_path, dpi=300, bbox_inches='tight')
#     plt.close()

#     # =================================================================================================
#     # 8. SISTEM PENYIMPANAN LOG (KODE ASLI ANDA)
#     # =================================================================================================
#     LOG_FILE_PATH = "experiment_log_custom_cnn.csv"

#     log_data = {
#         "Timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
#         "Fold_No": fold_no, # Tambahan untuk tracking fold
#         "Model": "Custom CNN (Dual-Pooling UV)",
#         "Total_Params": model.count_params(),
#         "Learning_Rate": LEARNING_RATE,
#         "Batch_Size": BATCH_SIZE, 
#         "Dropout_Rate": DROPOUT_RATE,
#         "Img_Size": IMG_SIZE,  
#         "Use_Class_Weights": "Yes (Dynamic K-Fold)",
#         "Accuracy": round(test_acc, 4),
#         "Avg_Confidence": round(avg_conf, 4),
#         "Confusion_Matrix": cm_str
#     }

#     for idx, label in enumerate(class_names):
#         metrics = report[label] 
#         log_data[f"C{idx+1}_Prec"] = round(metrics['precision'], 4)
#         log_data[f"C{idx+1}_Rec"] = round(metrics['recall'], 4)
#         log_data[f"C{idx+1}_F1"] = round(metrics['f1-score'], 4)

#     df_new_log = pd.DataFrame([log_data])

#     if not os.path.exists(LOG_FILE_PATH):
#         df_new_log.to_csv(LOG_FILE_PATH, index=False)
#     else:
#         df_new_log.to_csv(LOG_FILE_PATH, mode='a', header=False, index=False)
